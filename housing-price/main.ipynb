# %% [markdown]
# # Imports

# %%
# %pip install numpy pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\samim\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append('..')
from utils.regression import Regression, plot_data, prepare_data

# %% [markdown]
# # Data

# %%
data = pd.read_csv('data.csv')

x_columns = [
    "bedrooms",
    "bathrooms",
    "sqft_living",
    "sqft_lot",
    "floors",
    "waterfront",
    "view",
    "condition",
    "sqft_above",
    "sqft_basement",
    "yr_built",
    "yr_renovated",        
]
y_column = "price"

x_train, y_train = prepare_data(data, x_columns, y_column)

plot_data(data, x_columns, y_column)

# %% [markdown]
# # Train > Cost Plot > Accuracy

# %%
model = Regression(x_train, y_train)
model.train()
print("-" * 50)
model.plot_cost()
print("-" * 50)
model.train_accuracy()
# Out:
# Epoch >     0 | Cost: 0.000427
# Epoch >    55 | Cost: 0.000218
# Gradient Descent stopped due to increasing cost
# --------------------------------------------------
# --------------------------------------------------
# 0.Model Output > 0.007970175335756217 | Actual Output: 0.011771342610003762
# 460.Model Output > 0.0083802014933231 | Actual Output: 0.01414065438134637
# 920.Model Output > 0.0077869362772034845 | Actual Output: 0.01380218127115457
# 1380.Model Output > 0.008065696437860894 | Actual Output: 0.012974802557352389
# 1840.Model Output > 0.007820449911111589 | Actual Output: 0.012316660398646108
# 2300.Model Output > 0.008169549447166592 | Actual Output: 0.022527265889432116
# 2760.Model Output > 0.00836037115195688 | Actual Output: 0.020308386611508085
# 3220.Model Output > 0.008316172615425358 | Actual Output: 0.03798420458819105
# 3680.Model Output > 0.008450627235518758 | Actual Output: 0.018804061677322303
# ...
